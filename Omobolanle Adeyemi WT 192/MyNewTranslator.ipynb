# %%
        
print('Welcome to Globalcom')

complaint = {}
counter = 2

def complain():
    if complaint:

        
        user_id = input("Enter your 4 digit: ")
        new_complain = input('Please enter your complain: ')


        if user_id in complaint.keys() or new_complain in complaint.values():
            print('==========================')
            print('Data already exist, please try again!')
        else:
            complaint[user_id] = {
                         'Customer complain': new_complain}
           
                    
                
                
            
    else:                 
        user_id = input("Enter your 4 digit: ")
        new_complain = input('Please enter your complain: ')
        complaint[user_id] = {
                         'Customer complain': new_complain}
    counter = 1
    while counter:
        finish_complain = int(input('Enter 1 to submit, 2  to cancel: '))
        if finish_complain == 1:
            print('Thanks for choosing us, we will get back to you shortly')
            print(complaint)
        elif finish_complain == 2:
            break
        else:
            print('Invalid value, try again')
            
        

        
def main():
    runtime = 1
    
    while runtime:
        checker = int(input(
            'Enter 0 to complain and 1 to quit: '))

        if checker == 0:
            complain()        
        elif checker == 1:
            break
        else:
            print('Invalid value, try again')
    
            main()


main()

# %%
def address(pin):
    
   
    if pin in complaint.keys():
        addressing = complaint.get(pin)
        addressed = addressing.get('Customer complain')
        print ('You picked this complain: ' +addressed)
            
    else:
            print('Invalid value, try again')
            print('========================')



    
        


            
            
def main():
    runtime = 1
    print('Welcome to Globalcom')
    while runtime:
        checker = int(input(
            'Enter 0 to address complain and 1 to quit: '))

        if checker == 0:
            print(complaint)
            pin = input('Pick a complain by typing the user id: ')
            address(pin)        
        elif checker == 1:
            break
        else:
            
            print('Invalid value, try again')
    
            main()


main()

# %%
import json

# %%
import requests

url = "https://google-translate1.p.rapidapi.com/language/translate/v2/detect"

payload = "q={}.format(addressed)"
headers = {
    'content-type': "application/x-www-form-urlencoded",
    'accept-encoding': "application/gzip",
    'x-rapidapi-key': "5ece670de5msh0c84dc8a788fc46p118952jsn20798003aa83",
    'x-rapidapi-host': "google-translate1.p.rapidapi.com"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)

# %%
result = json.loads(response.text)

loan = result.values()

for gar in loan:
    babe = gar.values()
    
    for lim in babe:
        
        for kit in lim:
            
            for oil in kit:
                
                lim = oil.get("language")
                print(lim)

# %%
import requests

url = "https://google-translate1.p.rapidapi.com/language/translate/v2"

payload = "q={}&target=es&source=en".format(addressed,lim)
headers = {
    'content-type': "application/x-www-form-urlencoded",
    'accept-encoding': "application/gzip",
    'x-rapidapi-key': "5ece670de5msh0c84dc8a788fc46p118952jsn20798003aa83",
    'x-rapidapi-host': "google-translate1.p.rapidapi.com"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
